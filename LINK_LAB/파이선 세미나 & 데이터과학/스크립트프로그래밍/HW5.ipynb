# %% [markdown]
# # Assignment 5

# %% [markdown]
# ------
#
# #2010136140 허주성
# ______

# %% [markdown]
# ##[1번 문제] 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
# 클래스와 모듈 모두 이름공간을 정해 함수나 변수 등을 사용하고 정의함에 있어서 기능은 비슷하다.
#
# 하지만 클래스는 클래스 영역 내의 이름공간을 구성해 사용(class 생성 후 객체, 인스턴스로 사용)을 하고,
# 모듈은 파일 단위(.py)로 이름 공간을 구성해 코드들을 묶어 이를 사용하는 것이 다른 점이다. ( import 이용해서 호출 후 사용)

# %% [markdown]
# ______
# ##[2번 문제] 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %% [markdown]
# 다형성이란 상속 관계 내의 다른 클래스들의 인스턴스들이 같은 멤버 함수 호출에 대해 각각 다르게 반응하도록 하는 기능을 말한다.

# %%
class Money:
    def won(self):
        print '돈'
        
class chunwon(Money):
    def won(self):
        print '천원'
        
class manwon(Money):
    def won(self):
        print '만원'
        
class NoMoney(Money):
    pass

for each in (chunwon(),manwon(),NoMoney()):
    each.won()
# Out:
# 천원
# 만원
# 돈

# %% [markdown]
# ______
# ##[3번 문제] 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)

# %%
class Counter:
    def __init__(self,count,step=1):
        self.count=count
        self.step=step
    def __str__(self):
        return '[Count(step:%s)] %s' %(self.step,self.count)
    def incr(self):
        value=self.count+self.step
        self.count = value
    def __call__(self):
        value=self.count+self.step
        self.count = value
    def __coerce__(self, y):
        return self.count, y
    def __cmp__(self, other):
        return self.count,other
    
c=Counter(10)
d=Counter(10,2)
c.incr()
d.incr()
c()
d()
c=c+5
d=d-5
print c
print d
print
print c>10
print d>10
print c<10
print d<10
print c==17
print d!=9
# Out:
# 17
# 9
#
# True
# False
# False
# True
# True
# False

# %% [markdown]
# ______
# ##[4번 문제] 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 __init__(), __str()__(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
# Out:
# MySet: {1 ,2 ,3 }
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9 }

# %% [markdown]
# 1. __init__ : 객체에서 리스트 값을 받으면 append를 이용해 리스트화 시켜주고 eliminate_duplicate()를 호출한다.
# 2. __str__ 은 인스턴스 객체를 print할 때 자동으로 호출되며, 중복제거된 리스트를 출력시켜주는 역할을 수행한다. 이때 result[0:len(result)-2] + "}" 는 마지막 ', '를 지워주고 '}'를 붙이기 위해 사용한다.
# 3. eliminate_duplicate() 함수는 static method (정적 메소드)를 활용하였기 때문에 예로 MySet.eliminate_duplicate([1,2,2,3]) 이렇게도 호출 할 수 있다.하는 역할은 받아 들인 리스트의 중복을 제거해 다시 저장시켜 주는 역할을 수행한다.

# %% [markdown]
# ______
# ##[5번 문제] 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오 (정답을 각 요구사항별로 입력할 필요 없이 5번 문제에 대해 1개의 MySet 클래스 정의 코드를 제시하면 된다.)

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)
            
    def __or__(self,B):
        self=self+B
        MySet.eliminate_duplicate(self)
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
    def __and__(self,B):
        s=[]
        for e in self:
            for k in B:
                if e == k:
                    s.append(e)
        result = "MySet: {"
        for e in s:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
    def __sub__(self,B):
        x=[]
        for e in self:
            for k in B:
                if e == k:
                    x.append(e)
        
        for e in self:
            for k in x:
                if e == k:
                    self.remove(k)
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
    s=s|t
    print s
    s=MySet([1,2,3])
    t=MySet([3,4,5])
    s=s&t
    print s
    s=MySet([1,2,3])
    t=MySet([3,4,5])
    s=s-t
    print s
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# MySet: {1 ,2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# MySet: {3}
# MySet: {1 ,2}

# %% [markdown]
# ______
# ##[6번 문제] 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)
            
    def __or__(self,B):
        self=self+B
        MySet.eliminate_duplicate(self)
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
    def __and__(self,B):
        s=[]
        for e in self:
            for k in B:
                if e == k:
                    s.append(e)
        result = "MySet: {"
        for e in s:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
    def __sub__(self,B):
        x=[]
        for e in self:
            for k in B:
                if e == k:
                    x.append(e)
        
        for e in self:
            for k in x:
                if e == k:
                    self.remove(k)
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
if __name__ == "__main__":
    s = MySet([1, 2, 3,4,5,6])
    print len(s)
    print bool(s)
    print 2 in s
    print dir(MySet)
    print dir(len)
    print dir(bool)
    import keyword
    print keyword.kwlist
# Out:
# 6
# True
# True
# ['__add__', '__and__', '__class__', '__contains__', '__delattr__', '__delitem__', '__delslice__', '__dict__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getslice__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__setslice__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__weakref__', 'append', 'count', 'eliminate_duplicate', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# ['__call__', '__class__', '__cmp__', '__delattr__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']
# ['__abs__', '__add__', '__and__', '__class__', '__cmp__', '__coerce__', '__delattr__', '__div__', '__divmod__', '__doc__', '__float__', '__floordiv__', '__format__', '__getattribute__', '__getnewargs__', '__hash__', '__hex__', '__index__', '__init__', '__int__', '__invert__', '__long__', '__lshift__', '__mod__', '__mul__', '__neg__', '__new__', '__nonzero__', '__oct__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'bit_length', 'conjugate', 'denominator', 'imag', 'numerator', 'real']
# ['and', 'as', 'assert', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'exec', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'not', 'or', 'pass', 'print', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# 파이썬은 내장함수를 지원한다. 특정한 모듈을 import 할 필요 없이 바로 사용할 수 있다. MySet 클래스,len,bool 속성을 출력해보면 더 확실하게 알 수 있다. bool 내장함수는 __nonezero__() 메소드와 __len__() 메소드가 정의되어 있지 않으면 항상 True 반환한다.
# 파이썬에서 예약어로 지정된 keyword에 in이 있음을 알 수 있다.
# 따라서 오류없이 실행이 된다

# %% [markdown]
# ______
# ##[7번 문제] 이전 Assignment 3 (Assignment 4가 아님)의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하여 각 단어들에 대해 출현빈도를 사전형태({'world': 2, 'hello': 1, 'python': 1})로 저장하여 출력하는 것이었다. 이번에는 Assignment 3과 Assignment 4를 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오.

# %%
# -*- coding: utf-8 -*-
import urllib
import string

class WebWordsFrequency(list):

    def __init__(self,*args):
        for e in args:
            self.append(e)        
        
    def addUrl(self,value):
        self.append(value)
        
    def removeUrl(self,value):
        if value in self:
            self.remove(value)
            
    def listUrls(self):
        for e in self:
            print e
            
    def getWordsFrequency(self):
        
        if len(self)==0:
            print {}
        for e in self:
            source = urllib.urlopen(e).read()

            len_source = len(source)
            
            source_new = None
            i = 0
            while (i < len_source):
                found = False
                if (found != True and source[i] == "<" and source[i+1 : i+7].lower() == "script"):
                    found = True;
                    j = i + 7;
                    while (True):
                        if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+8].lower() == "script"):
                            #print "found - script"
                            source = source[:i] + ' ' + source[j+9:]
                            break
                        j = j + 1
                        if (j > len_source):
                            break
                    len_source = len(source)
                i = i + 1
            
            len_source = len(source)
            #print len_source
            
            i = 0
            while (i < len_source):
                found = False
                if (found != True and source[i] == "<" and source[i+1 : i+6].lower() == "style"):
                    found = True;
                    j = i + 6;
                    while (True):
                        if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+7].lower() == "style"):
                            #print "found - style"
                            source = source[:i] + ' ' + source[j+8:]
                            break
                        j = j + 1
                        if (j > len_source):
                            break
                    len_source = len(source)
                i = i + 1
            
            len_source = len(source)
            #print len_source
            
            i = 0
            while (i < len_source):
                found = False
                if (found != True and source[i] == "<"):
                    found = True;
                    j = i + 1;
                    while (True):
                        if (source[j] == ">"):
                            #print "found - HTML tag"
                            source = source[:i] + ' ' + source[j+1:]
                            break
                        j = j + 1
                        if (j > len_source):
                            break
                    len_source = len(source)
                i = i + 1
            
            len_source = len(source)
            
            
            source = unicode(source,'utf-8')
            c=0
            while(c<len(source)):
                if(source[c] in string.punctuation):
                    source = source[:c] + source[c+1:]
                    c=0
                c=c+1    
            words = source.split()
            
            
            #for word in words:
            #    print "'"+word+"'",
                
            diction = {}
            for words_key in words:
                #if already words in dictionary
                if(words_key in diction):
                    diction[words_key] = diction[words_key]+1
                #if words not in dictionary 
                else:
                    diction[words_key] = 1
            print
            print
            print '{',
            for k,v in diction.items():    
                print '\"',k,'\" :',v,',',
            print '}'
    def getMaxFrequencyWords(self):
         tmp=[]
         for e in self:
             source = urllib.urlopen(e).read()
             len_source = len(source)            
             source_new = None
             i = 0
             while (i < len_source):
                 found = False
                 if (found != True and source[i] == "<" and source[i+1 : i+7].lower() == "script"):
                     found = True;
                     j = i + 7;
                     while (True):
                         if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+8].lower() == "script"):
                             #print "found - script"
                             source = source[:i] + ' ' + source[j+9:]
                             break
                         j = j + 1
                         if (j > len_source):
                             break
                     len_source = len(source)
                 i = i + 1
             
             len_source = len(source)
             #print len_source
             
             i = 0
             while (i < len_source):
                 found = False
                 if (found != True and source[i] == "<" and source[i+1 : i+6].lower() == "style"):
                     found = True;
                     j = i + 6;
                     while (True):
                         if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+7].lower() == "style"):
                             #print "found - style"
                             source = source[:i] + ' ' + source[j+8:]
                             break
                         j = j + 1
                         if (j > len_source):
                             break
                     len_source = len(source)
                 i = i  + 1
            
             len_source = len(source)
             #print len_source
             
             i = 0
             while (i < len_source):
                 found = False
                 if (found != True and source[i] == "<"):
                     found = True;
                     j = i + 1;
                     while (True):
                         if (source[j] == ">"):
                             #print "found - HTML tag"
                             source = source[:i] + ' ' + source[j+1:]
                             break
                         j = j + 1
                         if (j > len_source):
                             break
                     len_source = len(source)
                 i  = i + 1
            
             len_source = len(source)
             
             
             source = unicode(source,'utf-8')
             c=0
             while(c<len(source)):
                 if(source[c] in string.punctuation):
                     source = source[:c] + source[c+1:]
                     c=0
                 c=c+1    
             words = source.split()
                           
             diction = {}
             for words_key in words:
                 #if already words in dictionary
                 if(words_key in diction):
                     diction[words_key] = diction[words_key]+1
                 #if words not in dictionary 
                 else:
                     diction[words_key] = 1
                    
             tmp = tmp + diction.items()

         
         diction = dict(tmp)
         print max(diction,key= lambda k: diction[k])

                         
        
w1=WebWordsFrequency('http://www.naver.com')
w1.addUrl('http://cse.koreatech.ac.kr')
print '***ListUrls'
w1.listUrls()
print
print '***getWordsFrequency()'
w1.getWordsFrequency()
print
print
print '***getMaxFrequencyWords()'
w1.getMaxFrequencyWords()
# Out:
# ***ListUrls
# http://www.naver.com
# http://cse.koreatech.ac.kr
#
# ***getWordsFrequency()
 1 , " 입시QA " : 1 , " 브로셔 " : 1 , " VoD " : 1 , " 어학강좌 " : 1 , " 어학 " : 1 , " 2015학년도 " : 1 , " 20131210 " : 1 , " 학생회 " : 1 , " 공학인증게시판 " : 1 , " 창의적 " : 1 , " 취업게시판 " : 1 , " 특성화 " : 7 , " 1000원 " : 1 , " 채용 " : 1 , " 2차 " : 1 , " 컴퓨터시스템응용 " : 1 , " 학회장부학 " : 1 , " 안내 " : 1 , " 취업조사2015 " : 1 , " 강좌 " : 1 , " KT " : 1 , " 20141208 " : 1 , " 20141209 " : 1 , " 직물설계CADCAM프로그램 " : 1 , " 20141201 " : 1 , " 대학원소개 " : 1 , " 20141207 " : 1 , " 최종 " : 1 , " 20141127 " : 1 , " 2학기 " : 2 , " 제6대 " : 1 , " 서식및양식자료실 " : 1 , " 컴퓨터 " : 2 , " 1 " : 2 , " 20140924 " : 1 , " 컴퓨터HW " : 1 , " 사물함 " : 1 , " 기말고사 " : 1 , " 20141212 " : 5 , " 설계1 " : 1 , " 20141210 " : 5 , " 디지털 " : 1 , " 사원 " : 1 , " KOICA " : 1 , " 익명게시판 " : 1 , " 1회 " : 1 , " 실습조교 " : 1 , " 3사…새 " : 1 , " 연구실소개 " : 1 , " 현대HCN " : 1 , " 일반자료실 " : 1 , " 포스터발표경진대회 " : 1 , " 졸업이수요건 " : 1 , " 인턴십 " : 1 , }
#
#
# ***getMaxFrequencyWords()
# ℃

# %% [markdown]
# ______
# ##[8번 문제] 7번 문제에서 정의한 WebWordsFrequency 클래스를 상속하여 OrderedWebWordsFrequency 클래스를 정의하고 슈퍼클래스에 정의된 getWordsFrequency() 메소드를 오버라이드 하여 단어 출현 빈도를 내림 차순으로 정렬하여 리스트로 출력하시오.

# %%
class OrderedWebWordsFrequency(WebWordsFrequency):
    def __init__(self,*args):
        for e in args:
            self.append(e)
            
    def getWordsFrequency(self):
        if len(self)==0:
            print '[]'
            
        tmp=[]
        for e in self:
            source = urllib.urlopen(e).read()
            len_source = len(source)            
            source_new = None
            i = 0
            while (i < len_source):
                found = False
                if (found != True and source[i] == "<" and source[i+1 : i+7].lower() == "script"):
                    found = True;
                    j = i + 7;
                    while (True):
                        if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+8].lower() == "script"):
                             #print "found - script"
                            source = source[:i] + ' ' + source[j+9:]
                            break
                        j = j + 1
                        if (j > len_source):
                            break
                    len_source = len(source)
                i = i + 1
            
            len_source = len(source)
            #print len_source
            
            i = 0
            while (i < len_source):
                found = False
                if (found != True and source[i] == "<" and source[i+1 : i+6].lower() == "style"):
                    found = True;
                    j = i + 6;
                    while (True):
                        if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+7].lower() == "style"):
                            #print "found - style"
                            source = source[:i] + ' ' + source[j+8:]
                            break
                        j = j + 1
                        if (j > len_source):
                            break
                    len_source = len(source)
                i = i  + 1
           
            len_source = len(source)
            #print len_source
            
            i = 0
            while (i < len_source):
                found = False
                if (found != True and source[i] == "<"):
                    found = True;
                    j = i + 1;
                    while (True):
                        if (source[j] == ">"):
                            #print "found - HTML tag"
                            source = source[:i] + ' ' + source[j+1:]
                            break
                        j = j + 1
                        if (j > len_source):
                            break
                    len_source = len(source)
                i  = i + 1
           
            len_source = len(source)
            
            
            source = unicode(source,'utf-8')
            c=0
            while(c<len(source)):
                if(source[c] in string.punctuation):
                    source = source[:c] + source[c+1:]
                    c=0
                c=c+1    
            words = source.split()
                          
            diction = {}
            for words_key in words:
                #if already words in dictionary
                if(words_key in diction):
                    diction[words_key] = diction[words_key]+1
                 #if words not in dictionary 
                else:
                    diction[words_key] = 1
                   
            tmp = tmp + diction.items()

        diction = dict(tmp)
        items=diction.items()
        items.sort(key=lambda k: k[1], reverse = True)
        print '[',
        for k,v in items:
            print '(\'',k,'\',',v,'),',
        print ']'
        
        print
        print
        li = list(tmp)
        li.sort(key=lambda k: k[1], reverse = True)
        print li

w4=OrderedWebWordsFrequency('http://www.naver.com','http://cse.koreatech.ac.kr')
w4.getWordsFrequency()
# Out:
#  [ (' ℃ ', 36 ), (' 네이버 ', 16 ), (' 현재 ', 15 ), (' 내일오전 ', 12 ), (' 눈 ', 12 ), (' 내일오후 ', 12 ), (' 상승 ', 11 ), (' 자동완성 ', 10 ), (' 검색어 ', 10 ), (' 10 ', 10 ), (' 구름많고 ', 10 ), (' 나눔글꼴 ', 8 ), (' 구름많음 ', 8 ), (' 내 ', 8 ), (' 맑음 ', 7 ), (' 도움말 ', 7 ), (' 끄기 ', 7 ), (' 특성화 ', 7 ), (' 검색어저장 ', 6 ), (' 켜기 ', 5 ), (' 20141212 ', 5 ), (' 20141211 ', 5 ), (' 20141210 ', 5 ), (' 레이어 ', 5 ), (' 책 ', 5 ), (' 바로가기 ', 5 ), (' 기능이 ', 5 ), (' 컴퓨터공학부 ', 5 ), (' 닫기 ', 5 ), (' 설치 ', 4 ), (' 한때 ', 4 ), (' 삭제 ', 4 ), (' txt ', 4 ), (' 있습니다 ', 4 ), (' 로그인 ', 4 ), (' 신고 ', 4 ), (' 구름조금 ', 4 ), (' 20 ', 4 ), (' 영화 ', 4 ), (' 오늘의 ', 4 ), (' 뮤직 ', 3 ), (' 흐림 ', 3 ), (' 30 ', 3 ), (' 1212사태 ', 3 ), (' 가끔 ', 3 ), (' nbsp ', 3 ), (' 홈 ', 3 ), (' 및 ', 3 ), (' 사이트 ', 3 ), (' 보기 ', 3 ), (' 서비스 ', 3 ), (' 앱 ', 3 ), (' 꺼져 ', 3 ), (' 블로그 ', 3 ), (' 60 ', 3 ), (' 기록 ', 3 ), (' 광고 ', 3 ), (' 전문보기 ', 2 ), (' 라이센스 ', 2 ), (' 에이핑크 ', 2 ), (' 타임스퀘어 ', 2 ), (' 공지 ', 2 ), (' 상황 ', 2 ), (' 웹툰 ', 2 ), (' 지역 ', 2 ), (' 등록 ', 2 ), (' 최근검색어 ', 2 ), (' 뉴스스탠드 ', 2 ), (' 다음 ', 2 ), (' 문자받기 ', 2 ), (' 뉴스 ', 2 ), (' 모집 ', 2 ), (' 모든 ', 2 ), (' 게임 ', 2 ), (' 스포츠 ', 2 ), (' 온스테이지 ', 2 ), (' 주요언론사 ', 2 ), (' 강남 ', 2 ), (' 이전 ', 2 ), (' 뮤직뱅크 ', 2 ), (' 이전페이지 ', 2 ), (' 설치하시겠습니까 ', 2 ), (' 열기 ', 2 ), (' 2학기 ', 2 ), (' 1 ',
(' 투데이 ', 1 ), (' 주의 ', 1 ), (' E북은 ', 1 ), (' 프로그램 ', 1 ), (' 3사에서 ', 1 ), (' new ', 1 ), (' 학부사진겔러리 ', 1 ), (' 연구 ', 1 ), (' 앱스토어 ', 1 ), (' 계속 ', 1 ), (' 카페명 ', 1 ), (' 설치하세요 ', 1 ), (' 홈페이지 ', 1 ), (' 방송기술 ', 1 ), (' 이유는 ', 1 ), (' 최근검색어에서 ', 1 ), (' 구독목록 ', 1 ), (' 습관middot상식hellip ', 1 ), (' 37 ', 1 ), (' 간식이벤트 ', 1 ), (' 원치않든 ', 1 ), (' 소환통보 ', 1 ), (' 불가피 ', 1 ), (' 본 ', 1 ), (' 후보에 ', 1 ), (' 완료 ', 1 ), (' 활성화되었습니다 ', 1 ), (' MY뉴스 ', 1 ), (' 공학인증안내 ', 1 ), (' 최초설치가 ', 1 ), (' 다음캐스트 ', 1 ), (' 사칭한 ', 1 ), (' 켤 ', 1 ), (' 자유게시판 ', 1 ), (' 이미지 ', 1 ), (' Corp ', 1 ), (' 재설치 ', 1 ), (' 오류 ', 1 ), (' 2015학년도 ', 1 ), (' 학생회 ', 1 ), (' 99 ', 1 ), (' 5위 ', 1 ), (' none ', 1 ), (' 39얕고 ', 1 ), (' 캠프 ', 1 ), (' 검색등록 ', 1 ), (' 컴퓨터시스템응용 ', 1 ), (' 해피빈 ', 1 ), (' 검색해 ', 1 ), (' 강좌 ', 1 ), (' 영자지 ', 1 ), (' 공룡 ', 1 ), (' 설치된 ', 1 ), (' 급행노선 ', 1 ), (' 사는 ', 1 ), (' 탈취악성코드 ', 1 ), (' 檢 ', 1 ), (' 컴퓨터HW ', 1 ), (' 브로셔 ', 1 ), (' 소개 ', 1 ), (' 않고 ', 1 ), (' 건강하기 ', 1 ), (' 것이 ', 1 ), (' 패밀리 ', 1 ), (' 신경질환39 ', 1 ), (' 왕 ', 1 ), (' date ', 1 ), (' 영어사전 ', 1 ), (' 알림 ', 1 ), (' 초대합니다 ', 1 ), (' 자동차 ', 1 ), (' 실습조 ...
#
#
# [(u'\u2103', 36), (u'\ub124\uc774\ubc84', 16), (u'\ud604\uc7ac', 15), (u'\ub0b4\uc77c\uc624\uc804', 12), (u'\ub0b4\uc77c\uc624\ud6c4', 12), (u'\ub208', 12), (u'\uc0c1\uc2b9', 11), (u'\uc790\ub3d9\uc644\uc131', 10), (u'\uac80\uc0c9\uc5b4', 10), (u'10', 10), (u'\uad6c\ub984\ub9ce\uace0', 10), (u'\ub098\ub214\uae00\uaf34', 8), (u'\uad6c\ub984\ub9ce\uc74c', 8), (u'\ub0b4', 8), (u'\ub9d1\uc74c', 7), (u'\ub3c4\uc6c0\ub9d0', 7), (u'\ub044\uae30', 7), (u'\ud2b9\uc131\ud654', 7), (u'\uac80\uc0c9\uc5b4\uc800\uc7a5', 6), (u'\ucf1c\uae30', 5), (u'\ub808\uc774\uc5b4', 5), (u'\ucc45', 5
'\ud574', 2), (u'\ubcf4\uc138\uc694', 2), (u'\uba54\ub274', 2), (u'\uc2e0\ubb38', 2), (u'\ud655\uc778\ub418\uc9c0', 2), (u'\uba54\uc778\uc744', 2), (u'\ub098\ub214\uae00\uaf34\uc744', 2), (u'\uc678\ubaa8\uc9c0\uc0c1\uc8fc\uc758', 2), (u'\ub098\ub214\uae00\uaf34\uc774', 2), (u'\uc9c0\uc5ed', 2), (u'\ub354\ubcf4\uae30', 2), (u'315', 2), (u'\uae30\ub2a5\uc744', 2), (u'03', 2), (u'\uac00\ub2a5\ud569\ub2c8\ub2e4', 2), (u'\uc9c0\uc2ddiN', 2), (u'\ub098\ub214\uae00\uaf34\ub85c', 2), (u'\ub2e4\uc6b4\ub85c\ub4dc', 2), (u'\ud750\ub9ac\uace0', 2), (u'\ub124\uc774\ubc84\ub97c', 2), (u'\uc0ac\uc6a9\uc790\uac00', 2), (u'\uac80\uc0c9', 2), (u'38', 2), (u'\ub2e4\uc2dc', 2), (u'\ub300\ud654\uc758', 2), (u'\uc0ac\uc6a9', 2), (u'\uce74\ud398', 2), (u'\uc804\uccb4\uc5b8\ub860\uc0ac', 2), (u'\ube44\ud22c\ube44', 2), (u'\uc1fc\ud551', 2), (u'1970', 2), (u'\uc5c6\uc2b5\ub2c8\ub2e4', 2), (u'\uc218', 2), (u'\uac1c\uc778', 2), (u'\ucde8\uc18c', 2), (u'\uac80\uc0c9\uc5b4\ub97c', 2), (u'\uc804\uccb4', 2), (u'\uae30\uc5c5\uc744', 2), (u'\uc9c0\ub3c4', 2), (u'\ub4f1\ub85d', 2), (u'\uc5f4\uae30', 2), (u'\uc1fc\ud551\uce90\uc2a4\ud2b8', 2), (u'\uae00\uaf34\uc124\uc815', 2), (u'\uc800\uc7a5', 2), (u'40', 2), (u'\uae30\uc220', 2), (u'\uc81c', 2), (u'\ubaa8\uc9d1', 2), (u'\uacf5\ud559\ubd80', 2), (u'\uacf5\uc9c0', 2), (u'\uc878\uc5c5\uc791\ud488', 2), (u'\uacf5\ud559\uc124\uacc4', 2), (u'\uc2e0', 2), (u'IT\uc735\ud569', 2), (u'20141014', 2), (u'2\ud559\uae30', 2), (u'\ucef4\ud4e8\ud130 ...

# %% [markdown]
# -------

# %% [markdown]
# [소감]
# --
# ####시험기간과 겹쳐서 뒤늦게 급하게 과제를 시작했는데 생각보다 어렵지 않아서 다행이었다. 하지만 이전 과제와는 다르게 서술형, 생각을 묻는 답들이 많아 고민도 많았다. 마지막 연계형 문제(7,8번)는 한글 출력이 안되 for문을 이용해 사전과 리스트처럼 보이게 출력을 시켰다. 또 그동안 내림차순 정렬을 할 때 sort을 mycmp를 사용해서 하면 무엇때문인지는 모르지만 항상 첫번째 요소가 빠져 고민이었는데 이번에 max함수를 사용하면서 lambda 함수도 같이 사용해 sorting을 하니 정상으로 출력되어 좋았다. 마지막 과제라고 하니 괜히 아쉽지만 정말 뿌듯하고 좋다.
