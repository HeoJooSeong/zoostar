# %%
#-*- coding:utf-8 -*-
import json
import requests
import random

app_key = ''
redirect_url = 'http://localhost:8888/tree?'
temp_key='-g-9n6g13LT8WI_hJiApRnh2N60yalune8IBo80Ew3BAopb9QAAAFzOKbJEg'

#인증코드 받아오기
oauth_url='https://kauth.kakao.com/oauth/authorize?client_id=64d312f7c5b7f292f7f379346dd1e6cd&redirect_uri=http://localhost:8888/tree?&response_type=code'

access_token =  ''
refresh_token = '-1A6bFxrkZl2UXiAdQopyNgAAAFzOKdOpw'

#메시지 전송 추가 인증
#print('https://kauth.kakao.com/oauth/authorize?client_id='+app_key+'&redirect_uri='+redirect_url+'&response_type=code&scope=talk_message')

def get_token():
    # 인증코드로 토큰 값 받아오기
    req_url = 'https://kauth.kakao.com/oauth/token'
    data = {'grant_type': 'authorization_code' ,'client_id':app_key ,'redirect_uri':redirect_url ,'code':temp_key}
    req = requests.post(req_url,data=data)
    #json 내 token, refresh_token 값
    return req.json()

def renew_token():
    # 리프레시 토큰으로 갱신하기
    req_url = 'https://kauth.kakao.com/oauth/token'
    data = {'grant_type': 'refresh_token' ,'client_id':app_key ,'refresh_token':refresh_token}
    req = requests.post(req_url,data=data)
    #json 내 token, refresh_token 값
    return req.json()

def make_message(text):
    temp = {
            'object_type': 'text',
            'text': text,
            'link': {
                'web_url': 'http://thinkonweb.com/',
                'mobile_web_url': 'http://thinkonweb.com/'
            },
            'button_title': '바로 확인',

            }
    return {"template_object":json.dumps(temp)}

def send_message(text):
    req_url='https://kapi.kakao.com/v2/api/talk/memo/default/send'
    req_header = {"Content-Type": "application/json","Content-Type": "x-www-form-urlencoded","Authorization": 'Bearer '+access_token}
    req = requests.post(req_url, headers=req_header, params = make_message(text))
    if req.status_code == 200: 
        print('success')
    else:
        print(req.text)

# %%
print(get_token())
# Out:
# {'access_token': 'FRPrMS4AT9BUjDvol72DJsW2WTkNcLbRZgT6ogopyNgAAAFzOKdOqA', 'token_type': 'bearer', 'refresh_token': 'vqPb_H47s_3MH_CX43vF-1A6bFxrkZl2UXiAdQopyNgAAAFzOKdOpw', 'expires_in': 21599, 'scope': 'account_email talk_message profile friends', 'refresh_token_expires_in': 5183999}

# %%
renew = renew_token()
access_token = renew['access_token']
lotto = random.sample(range(1,46),6)
lotto.sort()
send_message(str(lotto))
# Out:
# success

# %%
#naver
import bs4
import selenium
from selenium import webdriver
import time

path = 'C:\\Users\\zoost\\Downloads\\chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('https://www.naver.com')

element= driver.find_element_by_class_name('link_login')
element.click()

my_id=''
my_pw=''

driver.execute_script("document.getElementById('id').value = \'"+my_id+"\'")
time.sleep(1)
driver.execute_script("document.getElementById('pw').value = \'"+my_pw+"\'")
time.sleep(1)

element = driver.find_element_by_class_name('btn_global')
element.click()
time.sleep(1)
element = driver.find_element_by_class_name('ico_mail')
element.click()

page_source = driver.page_source
soup = bs4.BeautifulSoup(page_source,'html.parser')
print(soup)
# Out:
# <html lang="ko"><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/css/mail2_le.min.200416.css" rel="stylesheet" type="text/css"/>
# <link href="/css/mail_skin.min.200416.css" rel="stylesheet" type="text/css"/>
# <link href="//ssl.pstatic.net" rel="dns-prefetch"/>
# <link href="//lcs.naver.com" rel="dns-prefetch"/>
# <link href="//cc.naver.com" rel="dns-prefetch"/>
# <link href="//static.nid.naver.com" rel="dns-prefetch"/>
# <link href="//phinf.pstatic.net" rel="dns-prefetch"/>
# <link href="/css/mail_me.min.200416.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?2" rel="shortcut icon"/>
# <title>받은메일함(2) : 네이버 메일</title>
# <script type="text/javascript">
#
#
#
# 		var gnb_service = "mail";
# 		var gnb_logout = "http://www.naver.com";
# 		var gnb_template = "gnb_utf8";
# 		var gnb_brightness = 3;
# 		var gnb_item_hide_option = 8;
# 		var gnb_one_naver = 1;
#
#
# ...

# %%
#daum
import bs4
import selenium
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys


path = 'C:\\Users\\zoost\\Downloads\\chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('https://www.daum.net')

element= driver.find_element_by_class_name('link_kakaoid')
element.click()

my_id='@'
my_pw=''

driver.find_element_by_id('id_email_2').send_keys(my_id)

time.sleep(1)
driver.find_element_by_id('id_password_3').send_keys(my_pw)
driver.find_element_by_class_name('submit').click()

# %%
#fb
import bs4
import selenium
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys


path = 'C:\\Users\\zoost\\Downloads\\chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('https://www.facebook.com')

# element= driver.find_element_by_id('email')
# element.click()

my_id=''
my_pw=''

driver.find_element_by_id('email').send_keys(my_id)

time.sleep(1)
driver.find_element_by_id('pass').send_keys(my_pw)
driver.find_element_by_id('loginbutton').click()

# %%
    
#야구
import bs4
import selenium
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
# select=Select(driver.find_element_by_id("sch_bub_nm"))
# select.select_by_index(1) #select index value
# select.select_by_visible_text("Case2") # select visible text
# select.select_by_value("000201") # Select option value

path = 'C:\\Users\\zoost\\Downloads\\chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('http://www.korea-baseball.com/record/record/player_record?kind_cd=31')

element = driver.find_element_by_class_name('team').click()
driver.find_element_by_css_selector(".abs_select li[prop='190']").click()
driver.find_element_by_class_name('searchBtn').click()

text = driver.page_source

# %%
#기상청
import bs4
import selenium
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.support.select import Select


path = 'C:\\Users\\zoost\\Downloads\\chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('https://www.weather.go.kr/w/weather/today.do')

element = driver.find_element_by_class_name('serch-util-btn03').click()
time.sleep(0.5)
driver.find_element_by_css_selector("button[data-name='충청남도']").click()
time.sleep(0.5)
driver.find_element_by_css_selector("button[data-name='천안시서북구']").click()
time.sleep(0.5)
driver.find_element_by_css_selector("button[data-name='부성1동']").click()
time.sleep(0.5)
driver.find_element_by_class_name('sch-btn').click()

element = driver.find_elements_by_class_name('temp')

for i in element:
    print(i.text)

# text = driver.page_source
# Out:
# 24.5℃
# 체감온도(28℃)
# 23℃
# (26℃)
# 23℃
# (26℃)
# 22℃
# (25℃)
# 21℃
# (24℃)

# %%
#기상청
import bs4
import selenium
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.support.select import Select


path = 'C:\\Users\\zoost\\Downloads\\chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('https://www.weather.go.kr/w/weather/today.do')

element = driver.find_element_by_class_name('serch-util-btn03').click()
time.sleep(0.5)
driver.find_element_by_css_selector("button[data-name='충청남도']").click()
time.sleep(0.5)
driver.find_element_by_css_selector("button[data-name='천안시서북구']").click()
time.sleep(0.5)
driver.find_element_by_css_selector("button[data-name='부성1동']").click()
time.sleep(0.5)
driver.find_element_by_class_name('sch-btn').click()

element = driver.find_elements_by_class_name('temp')

for i in element:
    print(i.text)
