# %%
# import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
s = pd.Series(np.random.randn(10), index=np.arange(0, 100, 10))
s
# Out:
# 0    -0.854366
# 10   -0.917127
# 20    0.728717
# 30   -0.097290
# 40   -1.104855
# 50    0.132571
# 60   -1.106828
# 70   -1.364373
# 80    0.125896
# 90    0.237077
# dtype: float64

# %%
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0   1.021593 -0.701563 -0.333185 -0.853476
# 10  0.154637  0.175154  2.318786 -1.121526
# 20  1.429577 -0.132777  3.858998 -0.868205
# 30 -0.331277 -1.595098  2.808423 -2.316924
# 40 -1.846510 -0.976453  2.639500 -1.736409
# 50 -0.587435 -1.363951  3.024098 -1.676474
# 60 -2.487567 -1.679499  3.594509 -0.717126
# 70 -2.025676 -1.178873  2.332305 -1.094804
# 80 -2.892631 -1.570326  2.704143 -0.966059
# 90 -2.903865 -1.896505  2.708336 -2.545225

# %%
df.plot()

# %%
df['B'].plot()

# %%
#bar 

s2 = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))
s2
# Out:
# a    0.649505
# b    0.145764
# c    0.508204
# d    0.695042
# e    0.189514
# f    0.020633
# g    0.889139
# h    0.012271
# i    0.185787
# j    0.777697
# k    0.209968
# l    0.791200
# m    0.334526
# n    0.043841
# o    0.468378
# p    0.861319
# dtype: float64

# %%
s2.plot(kind='bar')

# %%
# 가로방향의 bar plot그리기
s2.plot(kind='barh')

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Genus"))
df2.plot(kind='bar')

# %%
df2.plot(kind='barh', stacked=True)

# %%
# histogram은 index가 필요없다.
s3 = pd.Series(np.random.normal(0, 1, size=200))
s3.hist()

# %%
s3.hist(bins=50)
#x 축의 구간 개수 bin

# %%
s3.hist(bins=100, normed=True)

# %%
#산점도(Scatter plot)

x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))
X = np.concatenate((x1, x2), axis=1)

df3 = pd.DataFrame(X, columns=["x1", "x2"])

# %%
plt.scatter(df3['x1'], df3['x2']) # x1이 x축, x2가 y축

# %%
plt.plot(np.random.randn(50), color = 'g', marker='o', linestyle='--')

# %%
plt.plot(np.random.randn(30), 'k.-')

# %% [markdown]
# ## color
# 값 색상
#
# "b" blue
#
# "g" green
#
# "r" red
#
# "c" cyan
#
# "m" magenta
#
# "y" yellow
#
# "k" black
#
# "w" white
#
# ## marker
# 값 마킹
#
# "." point
#
# "," pixel
#
# "o" circle
#
# "v" triangle_down
#
# "^" triangle_up
#
# "<" triangle_left
#
# ">" triangle_right
#
# "8" octagon
#
# "s" square
#
# "p" pentagon
#
# "*" star
#
# "h" hexagon
#
# "+" plus
#
# "x" x
#
# "D" diamond
#
# ## line style
# 값 라인 스타일
#
# "-" solid line
#
# "--" dashed line
#
# "-." dash-dotted line
#
# ":" dotted line
#
# "None" draw nothing

# %%
# %matplotlib inline

# %%
plt.figure()
plt.plot([1,2,3,4,5,6,7,87,8])
plt.show()

# %%
fig2, axes = plt.subplots(2, 3)

# %%
plt.figure()
plt.subplot(221)
plt.plot([1,2,3,4,5,6,7,8])

plt.subplot(222)
plt.plot([4,2,4,4,5,6,4,8])

plt.subplot(223)
plt.plot([9,7,6,5,3,1,2])

plt.subplot(224)
plt.plot([4,6,2,8,6,1,8,9])

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot([1,2,3,4,5,6,7,8])

plt.subplot(2,2,2)
plt.plot([9,7,6,5,3,1,2])

plt.subplot(2,1,2)
plt.plot([4,6,2,8,6,1,8,9])

# %%
from numpy.random import randn
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='k', alpha=0.5)
